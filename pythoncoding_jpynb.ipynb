# %% [markdown]
# <a href="https://colab.research.google.com/github/azlaslu736-byte/python-coding/blob/main/pythoncoding_jpynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n=int(input("totalnoofmonkeys"))
k=int(input("banana"))
j=int(input("peanut"))
m=int(input("bananapermonkey"))
p=int(input("peanutpermonkey"))

if n<=0 or k<=0 or j<=0 or m<=0 or p<=0:
  print("invalid input")

else:
 mb= m//k
 mp= p//j
 md=mb+mp

monkeyleft=n-md
print("noofmonkeysleft:",monkeyleft)
# Out:
# totalnoofmonkeys20
# banana2
# peanut3
# bananapermonkey12
# peanutpermonkey12
# noofmonkeysleft: 10

# %%
a=int(input("enter the value for a="))
b=int(input("enter the value for b="))
print("using temp")
temp=a
a=b
b=temp
print(a,b)

a=int(input("enter a value for a="))
b=int(input("enter a value for b="))
print("using,")
a,b=b,a
print(a,b)

a=int(input("enter a value for a="))
b=int(input("enter a value for b="))
print("using + and -")
d=a+b
e=a-b
print(d,e)

a=int(input("enter a value for a="))
b=int(input("enter a value for b="))
print("using^")
a=a^b
b=a^b
a=a^b
print("a,b:",a,b)
# Out:
# enter the value for a=10
# enter the value for b=5
# using temp
# 5 10
# enter a value for a=6
# enter a value for b=7
# using,
# 7 6
# enter a value for a=10
# enter a value for b=5
# using + and -
# 15 5
# enter a value for a=10
# enter a value for b=5
# using^
# a,b: 5 10

# %%
N=int(input("Enter max no. of candies:"))
K=int(input("Enter min no. of candies:"))
C=1
R=N
while(C==1):
  M=int(input("Enter amout of candies needed:"))
  if(M>N):
    print("invalid")
  else:
    R=R-M
    if(R<=K):
      R=N
    print("SOLD=",M)
    print("Remaining=",R)
    C=int(input("DO you want to continue(1or0):"))
# Out:
# SOLD= 2
# Remaining= 8

# %%
a=int(input("Enter The Number of list size:"))
list=[]
for I in range(a):
  b=int(input("Enter the elements in the list"))
  list.append(b)
print("List:",list)
# Out:
# Enter The Number of list size:5
# Enter the elements in the list2
# Enter the elements in the list3
# Enter the elements in the list4
# Enter the elements in the list5
# Enter the elements in the list6
# List: [2, 3, 4, 5, 6]

# %%
n = int(input("Enter the number of elements:"))
a = []
for I in range(n):
    a.append(int(input("Enter element:")))

print("The Smallest element is:", min(a))
# Out:
# Enter the number of elements:5
# Enter element:2
# Enter element:3
# Enter element:4
# Enter element:5
# Enter element:6
# The Smallest element is: 2

# %%
n = int(input("Enter the number of elements:"))
a = []
for I in range(n):
    a.append(int(input("Enter the element:")))
print("The Largest element is:", max(a))
# Out:
# Enter the number of elements:5
# Enter the element:3
# Enter the element:7
# Enter the element:4
# Enter the element:6
# Enter the element:8
# The Largest element is: 8

# %%
list=[]
a=int(input("Enter the number of elements: "))
for i in range(a):
  b=int(input("Enter the element: "))
  list.append(b)
print("SUM:",sum(list))
# Out:
# Enter the number of elements: 5
# Enter the element: 6
# Enter the element: 4
# Enter the element: 8
# Enter the element: 6
# Enter the element: 4
# SUM: 28

# %%
a=int(input("Enter the number of elements:"))
arr=[]
for I in range(a):
  b=int(input("Enter the element:"))
  arr.append(b)
print("Reversed Array",arr[::-1])
# Out:
# Enter the number of elements:5
# Enter the element:7
# Enter the element:5
# Enter the element:3
# Enter the element:2
# Enter the element:1
# Reversed Array [1, 2, 3, 5, 7]

# %%
list=[]
a=int(input("Enter the array limit:"))
for I in range(a):
    list.append(int(input("Enter the item:")))
b=int(input("Enter the element to find:"))
if b in list:
    print("Element exists")
else:
    print("Element not exists")
# Out:
# Enter the array limit:5
# Enter the item:6
# Enter the item:8
# Enter the item:3
# Enter the item:6
# Enter the item:2
# Enter the element to find:9
# Element not exists

# %%
n=int(input("Enter the list size:"))
list=[]
for i in range(n):
  a=int(input("enter the elements:"))
  list.append(a)
b=int(input("enter the element to be checked:"))
count=list.count(b)
print("occurance of",b,"is:",count)
# Out:
# Enter the list size:5
# enter the elements:3
# enter the elements:6
# enter the elements:7
# enter the elements:5
# enter the elements:7
# enter the element to be checked:7
# occurance of 7 is: 2

# %%
n=int(input("Enter the list size:"))
list=[]
for I in range(n):
  a=int(input("Enter the elements:"))
  list.append(a)
list.sort()
print("Second largest element is:",list[-2])
# Out:
# Enter the list size:5
# Enter the elements:3
# Enter the elements:8
# Enter the elements:5
# Enter the elements:9
# Enter the elements:6
# Second largest element is: 8

# %%
n=int(input("Enter the number of list element size:"))
list=[]
for I in range(n):
  a=int(input("enter the elements:"))
  list.append(a)
list.sort()
print("Sorted array is:",list)
# Out:
# Enter the number of list element size:5
# enter the elements:5
# enter the elements:8
# enter the elements:6
# enter the elements:4
# enter the elements:3
# Sorted array is: [3, 4, 5, 6, 8]
